# %%
#wordcloud
import wordcloud
text = 'python python hello data'
wc = wordcloud.WordCloud()
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# !pip install wordcloud
# Out:
# ...
#      -------------------------------------- 153.1/153.1 kB 4.6 MB/s eta 0:00:00
# ...

# %%
#wordcloud
text = {'python':10, 'hello':1,'data':5}
wc = wordcloud.WordCloud()
wc.generate_from_frequencies(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
text = '파이썬 파이썬 파이썬 시각화 시각화 데이터분석 오류 데이터'
font_path = '/Windows/Fonts/batang.tcc'
wc = wordcloud.WordCloud(font_path=font_path, stopwords=['오류','데이터'])
wc.generate_from_text(text)
wc.to_image()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8620\3671885261.py in <module>
#       2 font_path = '/Windows/Fonts/batang.tcc'
#       3 wc = wordcloud.WordCloud(font_path=font_path, stopwords=['오류','데이터'])
# ----> 4 wc.generate_from_text(text)
#       5 wc.to_image()
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     619         """
#     620         words = self.process_text(text)
# --> 621         self.generate_from_frequencies(words)
#     622         return self
#     623
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
# ...
