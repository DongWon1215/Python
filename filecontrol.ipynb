# %%
# 쓰기
f = open('text.txt','w')
f.write('12345')
f.close()

# %%
# 수정
f = open('text.txt','a')
f.write('12345')
f.close()
# Out:
# asdfg1234512345

# %%
# 읽기
f = open('text.txt','r')
data = f.read()
print(data)
list_temp = data.split(',')

f.close()
# Out:
# asdfg1234512345

# %%
# csv
f = open('list.csv','r')
data = f.read()
f.close()
print (data)
print(print(data))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7668\2347834340.py in <module>
#       1 # csv
#       2 f = open('list.csv','r')
# ----> 3 data = f.read()
#       4 f.close()
#       5 print (data)
#
# ~\anaconda3\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 0: invalid start byte

# %%
import csv
# read : 행의 데이터 -> list
f = open('list.csv','r')
data = csv.reader(f)
for item in data :
    print(i)
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7668\450890339.py in <module>
#       3 f = open('list.csv','r')
#       4 data = csv.reader(f)
# ----> 5 for item in data :
#       6     print(i)
#       7 f.close()
#
# ~\anaconda3\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 0: invalid start byte

# %%
# pandas csv read
import pandas as pd

data = pd.read_csv('list.csv', encoding='cp949')
data
# Out:
#     이름           전화번호  등번호
# 0  손흥민  010-1111-2222    7
# 1  이강인  010-1111-2223   19
# 2  김민재  010-1111-2224   20

# %%
# xls, xmls ( = excel)
import openpy as ob
data = xl.load.workbook('list.xlsx')
sheet = data['list']

for cell in sheet:
    print
print (i, value')

# %%
# 파이썬 데이터 형식 그대로 저장 -> read 읽기
import pickle

dta = ['a','b','c']
f = open('click_daum')
f.close()

# %%
f= open('oickle_data.txt','rb')
data = pickle.load(f)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7668\4566317.py in <module>
# ----> 1 f= open('oickle_data.txt','rb')
#       2 data = pickle.load(f)
#       3 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'oickle_data.txt'

# %%
f= open('oickle_data.txt','rb')
data = pickle.load(f)
print(data)
print(type(data))
f.close()

# %%
import requests
url = 'https://www.naver.com'
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
print(res.text.find('로그인'))
# Out:
# 6072

# %%
import bs4

# %%
# bs4.BeautifulSoup : html 형태로 변환해줌
data = "<div>안녕하세요</div>"
soup = bs4.BeautifulSoup(data)
print(soup)
# Out:
# <html><body><div>안녕하세요</div></body></html>

# %%
# find : 특정 선택자를 통해서 해당 엘리먼트를 검색 -> 반환
print(soup.find('div'))
print(soup.find('div').text)
# Out:
# <div>안녕하세요</div>
# 안녕하세요

# %%
soup = bs4.BeatifulSoup(res.text)
find_data = soup.find('a', attrs={'class':'issue'})
print(find_data)
